# %% [markdown]
# # Inspector tutorial

# %% [markdown]
# #### What is inspector ?
#    Vai_q_pytorch provides a function called inspector to help users diagnose neural network (NN) models under different device architectures. The inspector can predict target device assignments based on hardware constraints.The generated inspection report can be used to guide  users to modify or optimize the NN model, greatly reducing the difficulty and time of deployment. It is recommended to inspect float models before quantization.

# %%
import torch
import torch.nn as nn

# %%
# Import inspector API
# 
# Note:
# You can ignore warning message related with XIR. 
# The inspector relies on 'vai_utf' package. In conda env vitis-ai-pytorch in Vitis-AI docker, vai_utf is ready. But if vai_q_pytorch is installed by source code, it needs to install vai_utf in advance.
from pytorch_nndct.apis import Inspector
# Out:
# [VAIQ_NOTE]: Loading NNDCT kernels...

# %%
def init_weights(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)

# %%
class ResBlock(nn.Module):
    def __init__(self, channels: int):
        super().__init__()
        self.skip_conn = nn.Identity()
        self.block = nn.Sequential(
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding='same'),
            nn.LeakyReLU(0.2),
            nn.Conv2d(channels, channels, kernel_size=3, stride=1, padding='same'),
        )
        self.leakyrelu = nn.LeakyReLU(0.2)
        
    def forward(self, X):
        return self.leakyrelu(self.block(X) + self.skip_conn(X))

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net_noise = nn.Sequential(
            nn.Linear(100, 100 * 8 * 8),
            nn.Unflatten(1, (100, 8, 8)),
        )
        self.net_label = nn.Sequential(
            nn.Linear(1, 16 * 8 * 8),
            nn.Unflatten(1, (16, 8, 8)),
        )
        self.net = nn.Sequential(
            nn.ConvTranspose2d(116, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.LeakyReLU(0.2),
            ResBlock(64),
            
            nn.ConvTranspose2d(64, 128, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.LeakyReLU(0.2),
            ResBlock(128),
            
            nn.ConvTranspose2d(128, 256, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.LeakyReLU(0.2),
            ResBlock(256),
            
            nn.ConvTranspose2d(256, 128, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.LeakyReLU(0.2),
            ResBlock(128),
        
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.LeakyReLU(0.2),
            ResBlock(64),
        
            nn.Conv2d(64, 1, kernel_size=11, stride=1, padding=5),
            nn.Tanh(),
        )
        
        self.net_noise.apply(init_weights)
        self.net_label.apply(init_weights)
        self.net.apply(init_weights)
        
    def forward(self, noise: torch.Tensor, label: torch.Tensor):
        return self.net(torch.hstack([self.net_noise(noise), self.net_label(label)]))

# %%
# Specify a target name or fingerprint you want to deploy on
target = "DPUCAHX8L_ISA0_SP"
# Initialize inspector with target
inspector = Inspector(target)
# Out:
# [VAIQ_NOTE]: Inspector is on.

# %%
# Start to inspect the float model
# Note: visualization of inspection results relies on the dot engine.If you don't install dot successfully, set 'image_format = None' when inspecting.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Generator()

noises = torch.rand((1, 100), device=device).repeat((4, 1))
labels = torch.tensor([0.72, 0.7, 0.62, 0.51], device=device).reshape((4, 1))


inspector.inspect(model, (noises, labels,), device=device, output_dir="inspect", image_format="png")
# Out:
# [VAIQ_NOTE]: =>Start to inspect model...
#
# [VAIQ_NOTE]: =>Quant Module is in 'cuda'.
#
# [VAIQ_NOTE]: =>Parsing Generator...
#
# [VAIQ_NOTE]: Start to trace and freeze model...
#
# [VAIQ_NOTE]: The input model nndct_st_Generator_ed is torch.nn.Module.
#
# [VAIQ_NOTE]: Finish tracing.
#
# [VAIQ_NOTE]: Processing ops...
# ██████████████████████████████████████████████████| 45/45 [00:00<00:00, 947.51it/s, OpInfo: name = return_0, type = Retu
# [VAIQ_WARN][QUANTIZER_TORCH_FLOAT_OP]: The quantizer recognize new op `aten::hstack` as a float operator by default.
#
# [VAIQ_WARN][QUANTIZER_TORCH_FLOAT_OP]: The quantizer recognize new op `aten::_convolution_mode` as a float operator by default.
#
# [VAIQ_WARN][QUANTIZER_TORCH_FLOAT_OP]: The quantizer recognize new op `aten::unflatten` as a float operator by default.
#
# [VAIQ_NOTE]: =>Doing weights equalization...
#
# [VAIQ_WARN][QUANTIZER_TORCH_LEAKYRELU]: Preserve negative_slope(0.2) of LeakyReLU without quantization.
#
# [VAIQ_NOTE]: =>Quantizable module is generated.(inspect/Generator.py)
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[0]/ret.15, op type:nndct_conv_transpose_2d, output shape: [4, 16, 16, 64]
# node name:Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17, op type:nndct_leaky_relu, output shape: [4, 16, 16, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/ret.13_swim_transpose_0's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[3]/ret.29, op type:nndct_conv_transpose_2d, output shape: [4, 32, 32, 128]
# node name:Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31, op type:nndct_leaky_relu, output shape: [4, 32, 32, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[2]/LeakyReLU[leakyrelu]/ret.27's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[6]/ret.43, op type:nndct_conv_transpose_2d, output shape: [4, 64, 64, 256]
# node name:Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45, op type:nndct_leaky_relu, output shape: [4, 64, 64, 256]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[5]/LeakyReLU[leakyrelu]/ret.41's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[12]/ret.71, op type:nndct_conv_transpose_2d, output shape: [4, 256, 256, 64]
# node name:Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73, op type:nndct_leaky_relu, output shape: [4, 256, 256, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[11]/LeakyReLU[leakyrelu]/ret.69's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_18:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[9]/ret.57, op type:nndct_conv_transpose_2d, output shape: [4, 128, 128, 128]
# node name:Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59, op type:nndct_leaky_relu, output shape: [4, 128, 128, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[8]/LeakyReLU[leakyrelu]/ret.55's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[2]/ret.79_swim_transpose_5, op type:nndct_permute, output shape: [4, 256, 256, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[2]/ret.79's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73_sink_transpose_4, op type:nndct_permute, output shape: [4, 64, 256, 256]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[2]/ret.23_swim_transpose_1, op type:nndct_permute, output shape: [4, 16, 16, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[2]/ret.23's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31_sink_transpose_1, op type:nndct_permute, output shape: [4, 128, 32, 32]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/ret.13_swim_transpose_0, op type:nndct_permute, output shape: [4, 8, 8, 116]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/ret.13's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[2]/ret.37_swim_transpose_2, op type:nndct_permute, output shape: [4, 32, 32, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[2]/ret.37's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[2]/ret.65_swim_transpose_4, op type:nndct_permute, output shape: [4, 128, 128, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[2]/ret.65's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[2]/ret.51_swim_transpose_3, op type:nndct_permute, output shape: [4, 64, 64, 256]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[2]/ret.51's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17_sink_transpose_0, op type:nndct_permute, output shape: [4, 64, 16, 16]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59_sink_transpose_3, op type:nndct_permute, output shape: [4, 128, 128, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for reshape_fix_1:
# node name:Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45_sink_transpose_2, op type:nndct_permute, output shape: [4, 256, 64, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net_label]/Linear[0]/ret.9, op type:nndct_dense, output shape: [4, 1024]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::input_1's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[0]/ret.15, op type:nndct_conv_transpose_2d, output shape: [4, 16, 16, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/ret.13_swim_transpose_0's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[3]/ret.29, op type:nndct_conv_transpose_2d, output shape: [4, 32, 32, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[2]/LeakyReLU[leakyrelu]/ret.27's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I20231028 19:12:06.995985   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:06.996028   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:06.996034   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:06.996107   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_nndct_leaky_relu_2C3HyZ6wR9GSaskv, with op num: 9
# I20231028 19:12:06.996111   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.004937   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_0__ret_15, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# I20231028 19:12:07.005085   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.005102   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.011241   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.011272   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.011277   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.011366   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_nndct_leaky_relu_OP48XZY5WJuzpcda, with op num: 9
# I20231028 19:12:07.011371   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.019780   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_3__ret_29, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# I20231028 19:12:07.019946   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.019965   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.025713   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.025750   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.025755   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.025812   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_nndct_leaky_relu_w29aE7IkonmZqMrA, with op num: 9
# I20231028 19:12:07.025815   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.051383   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_6__ret_43, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# I20231028 19:12:07.051463   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.051477   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.056705   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.056747   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.056752   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.056814   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_nndct_leaky_relu_Mj1CDLlA9ukcex7v, with op num: 9
# I20231028 19:12:07.056818   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.065331   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_12__ret_71, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# I20231028 19:12:07.065414   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.065428   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.071954   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.072003   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.072008   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.072069   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_nndct_leaky_relu_B8MLxpOzgTW23aqm, with op num: 9
# I20231028 19:12:07.072072   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.097414   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_9__ret_57, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# I20231028 19:12:07.097492   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.097505   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.107364   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.107425   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.107431   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.107496   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_R3Cif2lF0ZmIEDA9, with op num: 4
# I20231028 19:12:07.107498   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.109369   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ResBlock_14__Sequential_block__Conv2d_2__ret_79_swim_transpose_5, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.109438   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.109452   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.114370   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.114420   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.114425   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.114490   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_rBNZziPD3ghUMJbx, with op num: 4
# I20231028 19:12:07.114491   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.116042   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_13__ret_73_sink_transpose_4, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.116101   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.116113   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.119906   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.119941   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.119946   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.120010   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_DsPmAHE3Uf28wMyV, with op num: 4
# I20231028 19:12:07.120013   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.121604   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ResBlock_2__Sequential_block__Conv2d_2__ret_23_swim_transpose_1, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.121661   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.121675   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.125635   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.125674   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.125679   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.125743   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_fb9Y4rzS2D5WL1Kp, with op num: 4
# I20231028 19:12:07.125746   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.127267   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_4__ret_31_sink_transpose_1, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.127319   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.127332   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.130688   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.130793   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.130807   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.130882   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_0UZnMj8pLOGvc1hD, with op num: 4
# I20231028 19:12:07.130885   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.132479   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_ret_13_swim_transpose_0, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.132534   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.132545   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.136361   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.136412   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.136420   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.136528   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_Yw7nzqAVixPFus6S, with op num: 4
# I20231028 19:12:07.136531   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.138069   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ResBlock_5__Sequential_block__Conv2d_2__ret_37_swim_transpose_2, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.138181   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.138197   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.142391   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.142434   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.142439   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.142503   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_Q24wqgHlFoDYRb3p, with op num: 4
# I20231028 19:12:07.142505   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.144127   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ResBlock_11__Sequential_block__Conv2d_2__ret_65_swim_transpose_4, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.144186   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.144198   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.148131   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.148167   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.148172   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.148234   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_Gte8ExZKRnbF376z, with op num: 4
# I20231028 19:12:07.148237   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.149817   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__ResBlock_8__Sequential_block__Conv2d_2__ret_51_swim_transpose_3, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.149873   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.149885   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.153558   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.153599   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.153604   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.153667   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_WhHJCTwbMYxgBNkj, with op num: 4
# I20231028 19:12:07.153669   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.155207   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_1__ret_17_sink_transpose_0, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.155314   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.155330   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.159860   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.159904   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.159909   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.159974   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_t8Yw7EQTjkCzaWiI, with op num: 4
# I20231028 19:12:07.159977   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.161525   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_10__ret_59_sink_transpose_3, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.161579   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.161592   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.165271   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.165308   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.165313   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.165375   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_permute_txYvnLQH8FVrakGc, with op num: 4
# I20231028 19:12:07.165377   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# W20231028 19:12:07.166932   586 PartitionPass.cpp:4160] [UNILOG][WARNING] xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_7__ret_45_sink_transpose_2, type = transpose} has been assigned to CPU.
# I20231028 19:12:07.166990   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.167002   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.177630   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.177668   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.177673   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.177738   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_dense_ZQtfiqHols1GMhvd, with op num: 8
# I20231028 19:12:07.177742   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.181257   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 2, DPU subgraph number 0
# I20231028 19:12:07.181281   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.186112   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.186159   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.186165   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.186230   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_NDksjdcPC3W54AbM, with op num: 8
# I20231028 19:12:07.186232   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.193862   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.193897   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.199282   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.199344   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[6]/ret.43, op type:nndct_conv_transpose_2d, output shape: [4, 64, 64, 256]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[5]/LeakyReLU[leakyrelu]/ret.41's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[12]/ret.71, op type:nndct_conv_transpose_2d, output shape: [4, 256, 256, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[11]/LeakyReLU[leakyrelu]/ret.69's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/Conv2d[15]/ret.85, op type:nndct_conv2d, output shape: [4, 256, 256, 1]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[14]/LeakyReLU[leakyrelu]/ret.83's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net_noise]/Linear[0]/ret.5, op type:nndct_dense, output shape: [4, 6400]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::input_0's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for convlike_fix_20:
# node name:Generator::Generator/Sequential[net]/ConvTranspose2d[9]/ret.57, op type:nndct_conv_transpose_2d, output shape: [4, 128, 128, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[8]/LeakyReLU[leakyrelu]/ret.55's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_24:
# node name:Generator::Generator/Sequential[net]/ResBlock[2]/ret.25, op type:nndct_elemwise_add, output shape: [4, 16, 16, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[2]/ret.23_swim_transpose_1's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_24:
# node name:Generator::Generator/Sequential[net]/ResBlock[8]/ret.53, op type:nndct_elemwise_add, output shape: [4, 64, 64, 256]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[2]/ret.51_swim_transpose_3's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_24:
# node name:Generator::Generator/Sequential[net]/ResBlock[11]/ret.67, op type:nndct_elemwise_add, output shape: [4, 128, 128, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[2]/ret.65_swim_transpose_4's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_24:
# node name:Generator::Generator/Sequential[net]/ResBlock[14]/ret.81, op type:nndct_elemwise_add, output shape: [4, 256, 256, 64]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[2]/ret.79_swim_transpose_5's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: Find subgraph for eltwise_fix_24:
# node name:Generator::Generator/Sequential[net]/ResBlock[5]/ret.39, op type:nndct_elemwise_add, output shape: [4, 32, 32, 128]
#
#
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[2]/ret.37_swim_transpose_2's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_WARN][QUANTIZER_TORCH_INSPECTOR_PATTERN]: The First dimension of pattern data node Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31's  shape is 4 > 1 which will be set to 1 temporarily for pattern matching.
#
# [VAIQ_NOTE]: The operators assigned to the CPU are as follows(see more details in 'inspect/inspect_DPUCAHX8L_ISA0_SP.txt'):
# node name                                                                                              op Type                  hardware constraints
# -----------------------------------------------------------------------------------------------------  -----------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Generator::Generator/Sequential[net_noise]/Unflatten[1]/ret.7                                          aten::unflatten          aten::unflatten can't be converted to XIR.
# Generator::Generator/Sequential[net_label]/Linear[0]/ret.9                                             nndct_dense              Try to assign nndct_dense_ZQtfiqHols1GMhvd to DPU failed.
# Generator::Generator/Sequential[net_label]/Unflatten[1]/ret.11                                         aten::unflatten          aten::unflatten can't be converted to XIR.
# Generator::Generator/ret.13                                                                            aten::hstack             aten::hstack can't be converted to XIR.
# Generator::Generator/ret.13_swim_transpose_0                                                           nndct_permute            xir::Op{name = Generator__Generator_ret_13_swim_transpose_0, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17                                               nndct_leaky_relu         xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_0__ret_15, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# Generator::Generator/Sequential[net]/LeakyReLU[1]/ret.17_sink_transpose_0                              nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_1__ret_17_sink_transpose_0, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[0]/ret.19                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/LeakyReLU[1]/ret.21                 nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[2]/ret.23                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[2]/Sequential[block]/Conv2d[2]/ret.23_swim_transpose_1   nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__ResBlock_2__Sequential_block__Conv2d_2__ret_23_swim_transpose_1, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[2]/LeakyReLU[leakyrelu]/ret.27                           nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31                                               nndct_leaky_relu         xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_3__ret_29, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# Generator::Generator/Sequential[net]/LeakyReLU[4]/ret.31_sink_transpose_1                              nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_4__ret_31_sink_transpose_1, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[0]/ret.33                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/LeakyReLU[1]/ret.35                 nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[2]/ret.37                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[5]/Sequential[block]/Conv2d[2]/ret.37_swim_transpose_2   nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__ResBlock_5__Sequential_block__Conv2d_2__ret_37_swim_transpose_2, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[5]/LeakyReLU[leakyrelu]/ret.41                           nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45                                               nndct_leaky_relu         xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_6__ret_43, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# Generator::Generator/Sequential[net]/LeakyReLU[7]/ret.45_sink_transpose_2                              nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_7__ret_45_sink_transpose_2, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[0]/ret.47                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/LeakyReLU[1]/ret.49                 nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[2]/ret.51                    aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[8]/Sequential[block]/Conv2d[2]/ret.51_swim_transpose_3   nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__ResBlock_8__Sequential_block__Conv2d_2__ret_51_swim_transpose_3, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[8]/LeakyReLU[leakyrelu]/ret.55                           nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59                                              nndct_leaky_relu         xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_9__ret_57, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# Generator::Generator/Sequential[net]/LeakyReLU[10]/ret.59_sink_transpose_3                             nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_10__ret_59_sink_transpose_3, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[0]/ret.61                   aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/LeakyReLU[1]/ret.63                nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[2]/ret.65                   aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[11]/Sequential[block]/Conv2d[2]/ret.65_swim_transpose_4  nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__ResBlock_11__Sequential_block__Conv2d_2__ret_65_swim_transpose_4, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[11]/LeakyReLU[leakyrelu]/ret.69                          nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73                                              nndct_leaky_relu         xir::Op{name = Generator__Generator_Sequential_net__ConvTranspose2d_12__ret_71, type = transposed-conv2d-fix} has been assigned to CPU: [DPU does not support activation type: LEAKYRELU.].
# Generator::Generator/Sequential[net]/LeakyReLU[13]/ret.73_sink_transpose_4                             nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__LeakyReLU_13__ret_73_sink_transpose_4, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[0]/ret.75                   aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/LeakyReLU[1]/ret.77                nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[2]/ret.79                   aten::_convolution_mode  aten::_convolution_mode can't be converted to XIR.
# Generator::Generator/Sequential[net]/ResBlock[14]/Sequential[block]/Conv2d[2]/ret.79_swim_transpose_5  nndct_permute            xir::Op{name = Generator__Generator_Sequential_net__ResBlock_14__Sequential_block__Conv2d_2__ret_79_swim_transpose_5, type = transpose} has been assigned to CPU.
# Generator::Generator/Sequential[net]/ResBlock[14]/LeakyReLU[leakyrelu]/ret.83                          nndct_leaky_relu         nndct_leaky_relu can't be assigned to DPU.
# Generator::Generator/Sequential[net]/Tanh[16]/ret                                                      nndct_tanh               nndct_tanh can't be assigned to DPU.
# I20231028 19:12:07.199353   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.199460   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_ypRavjwnshBE3qOX, with op num: 8
# I20231028 19:12:07.199476   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.207454   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.207492   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.213645   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.213686   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.213692   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.213758   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_s03z8njiIKAdaYB9, with op num: 8
# I20231028 19:12:07.213760   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.238698   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.238729   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.243664   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.243695   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.243700   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.243762   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_T8bA6HFrI0pqKldO, with op num: 8
# I20231028 19:12:07.243764   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.251766   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.251793   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.256929   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.256968   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.256973   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.257031   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv2d_96sXSzaADoUgCEpR, with op num: 8
# I20231028 19:12:07.257033   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.260125   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.260151   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.265467   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.265511   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.265515   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.265578   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_dense_TKWwmbfUIAjgLiy4, with op num: 8
# I20231028 19:12:07.265581   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.287106   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.287140   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.293292   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.293334   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.293339   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.293439   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_conv_transpose_2d_VKYZHsp8aydF7APS, with op num: 8
# I20231028 19:12:07.293443   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.318018   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 3, DPU subgraph number 1
# I20231028 19:12:07.318053   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.326632   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.326670   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.326678   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.326741   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_I6B5NLHPGslx1yfR, with op num: 6
# I20231028 19:12:07.326745   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.328979   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20231028 19:12:07.329005   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.334810   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.334848   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.334853   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.334918   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_FnGdRsbJkc0ejpSm, with op num: 6
# I20231028 19:12:07.334921   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.337023   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20231028 19:12:07.337042   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.343039   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.343082   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.343086   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.343150   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_G7czWIXie028xj9p, with op num: 6
# I20231028 19:12:07.343153   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.345121   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20231028 19:12:07.345144   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.352671   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.352713   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.352718   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.352824   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_YK52NtGbzpjcJWao, with op num: 6
# I20231028 19:12:07.352831   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.354707   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20231028 19:12:07.354727   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# I20231028 19:12:07.360524   586 compile_pass_manager.cpp:352] [UNILOG][INFO] Compile mode: dpu
# I20231028 19:12:07.360585   586 compile_pass_manager.cpp:353] [UNILOG][INFO] Debug mode: null
# I20231028 19:12:07.360595   586 compile_pass_manager.cpp:357] [UNILOG][INFO] Target architecture: DPUCAHX8L_ISA0_SP
# I20231028 19:12:07.360713   586 compile_pass_manager.cpp:465] [UNILOG][INFO] Graph name: nndct_elemwise_add_mwYZvUxnXe56fs70, with op num: 6
# I20231028 19:12:07.360728   586 compile_pass_manager.cpp:478] [UNILOG][INFO] Begin to compile...
# I20231028 19:12:07.362656   586 compile_pass_manager.cpp:489] [UNILOG][INFO] Total device subgraph number 4, DPU subgraph number 1
# I20231028 19:12:07.362676   586 compile_pass_manager.cpp:504] [UNILOG][INFO] Compile done.
# [VAIQ_NOTE]: Dot image is generated.(inspect/inspect_DPUCAHX8L_ISA0_SP.png)
#
# [VAIQ_NOTE]: =>Finish inspecting.

# %% [markdown]
# ##### Inspection result anaysis:
# 1. In this toy model, there are three operations will be assigned to cpu. The reasons for being allocated to the CPU are shown in the column of hardware constraints.
# 2. The target device of an input node is determined by its consumer.
# 3. Here, we found that a special permute operation("ToyModel::ToyModel/AdaptiveAvgPool2d[adaptive_avg_pool2d]/146_sink_transpose_0") is inserted by quantizer. Due to data layout difference between Pytorch('NCHW') and XIR('NHWC'), if quantizer inserts some permutes(which the node message in inspect file will inform us about), these permutes may prevent the entire model from being deployed to the target device. Sometimes, we can cancel out this automatically inserted permute by inserting a permute in the original float model, sometimes, we can't.
# 4. If you want more details about the inspection, see the inspection report under the output directory you specified.
# 5. The dot image can help you to analyze inspection result in a more intuitive way. "svg" and "png" format are both supported.

# %%
# Show the dot image
from IPython.display import Image
Image('inspect/inspect_DPUCAHX8L_ISA0_SP.png')

# %% [markdown]
# ##### How to deploy this entire model on DPU:
# 1. Find the location of CPU operations in original model. All the details of operations are shown in inspect_{target}.txt, including source range, points to a source which is a stack track and helps to find the exact location of this operation in source code. Take resize op as a example, from source range, we can find the location of resize op in #3 input block line 11.
# node name: ToyModel::ToyModel/Upsample[upsample]/input.3
# ...
# op type: resize
# ...
# source range:
# ...
# <font color=red>ipython-input-3-7ec1fc6b678f(11): forward</font>
# ...

# %% [markdown]
# 2. Modify the original model according to the hardware constrains message and try to cancel out the permute inserted by quantizer with by inserting a permute in the original float model(more details see hints in inspect_{target}.txt)

# %%
# Modified the ToyModel
class ModifiedToyModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.upsample = torch.nn.Upsample(scale_factor=2, mode='nearest')  # set mode = "nearest"
        self.conv = torch.nn.Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
        self.relu = torch.nn.ReLU()
        self.adaptive_avg_pool2d = torch.nn.AdaptiveAvgPool2d(output_size=2)
        
    def forward(self, x):
        x = self.upsample(x)
        x = self.conv(x)
        x = self.relu(x)
        x = self.adaptive_avg_pool2d(x)
        x = x.permute(0, 2, 3, 1) # insert a permute to cancel out the permute inserted by quantizer.
        x = x.reshape(x.size(0), -1)
        return x

# %%
# Inspect the modified model
model = ModifiedToyModel()
inspector.inspect(model, (dummy_input,), device=device, output_dir="inspect", image_format="png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Inspect the modified model
#       2 model = ModifiedToyModel()
# ----> 3 inspector.inspect(model, (dummy_input,), device=device, output_dir="inspect", image_format="png")
#
# NameError: name 'dummy_input' is not defined

# %%
# Show the dot image
from IPython.display import Image
Image('inspect/inspect_DPUCAHX8L_ISA0_SP.png')

# %% [markdown]
# ##### Inspection result anaysis:
# Finally, under the guidance of the inspector, the entire ToyModel can be deployed on the DPU.
